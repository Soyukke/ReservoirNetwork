# %%
using Pkg;Pkg.activate("..")
using Revise,Plots
gr()
using ReservoirNetwork

# %%
outs, data = ReservoirNetwork.example()
# Out:
# (Any[0.0f0, 0.023721177f0, 0.06541842f0, 0.120197944f0, 0.18389404f0, 0.25297135f0, 0.32446015f0, 0.3959215f0, 0.46543312f0, 0.53157413f0  …  -0.5461522f0, -0.49076825f0, -0.4330316f0, -0.3732714f0, -0.31184915f0, -0.24915016f0, -0.18557349f0, -0.12151849f0, -0.057370942f0, 0.006511065f0], Float32[0.0, 0.06279052, 0.12533323, 0.18738131, 0.24868989, 0.309017, 0.36812454, 0.42577928, 0.48175368, 0.5358268  …  -0.5358268, -0.48175368, -0.42577928, -0.36812454, -0.309017, -0.24868989, -0.18738131, -0.12533323, -0.06279052, -7.3478806f-16])

# %%
plot(outs, label="予想"; fontfamily="Arial")
plot!(data, label="sin(x)")
